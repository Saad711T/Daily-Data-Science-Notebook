# %% [markdown]
# # OOP in Python

# %% [markdown]
# Object Oriented programming or OOP is a paradigm based on making with structured styles where entities is "objects" , containing data is (attributes) and behavior (methods) .

# %% [markdown]
# ### Class

# %%
class MyClass:
    x=5

print(MyClass)
# Out:
# <class '__main__.MyClass'>
