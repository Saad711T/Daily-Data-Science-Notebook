# %% [markdown]
# # Python Basics notebook

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1280px-Python-logo-notext.svg.png" width ="400px" />

# %% [markdown]
# Python is a high-level and OOP programming language , Widely used in Web development , Cybersecurity , Automation and Data Science/ML .

# %% [markdown]
# ### Print

# %%
print("Hello world")

# أمر الطباعة - Print command
# Out:
# Hello world

# %% [markdown]
# ### Variables

# %%
x = 10

# متغير - Variable
# ولانحتاج لتعريف نوعه عكس جافا وسي بلس بلس , المتغير من قيمته يتم تعريفه من اللغة نفسها
# It's dynamic variable so it's dont require identifing data type before variable like java or c++.

# %% [markdown]
# ### Print a variable

# %%
print(x)
# Out:
# 10

# %% [markdown]
# ### Print a variable with string

# %%
print("x is  : ",x)
# Out:
# x is  :  10

# %% [markdown]
# ### Using libraries :

# %%
import time
import os
import math

# يمكننا استخدام المكتبات الآتية في مشروعنا
# We can used libraries in our code after import it.

# %% [markdown]
# ### Downloading external library :

# %% [markdown]
# Typing this and run it at your local terminal :
#
# `pip install *library name* `

# %% [markdown]
# For example :

# %%
# !pip install pandas

# %% [markdown]
# ### Subname for library :

# %%
# اختصار اسم المكتبة

import pandas as pd
import numpy as np

# لإستخدام مكتبة نمباي عليك التقيد بإسمها المختصر
# For using NumPy , You must using it with his subname "np".

# %% [markdown]
# ### Input and Output (I/O)

# %%
# أمر الانبوت/الادخال

yourname = input("Enter your name : ")

print ("Your name is : " , yourname)
# Out:
# Your name is :  Saad

# %% [markdown]
# ### If/Else :

# %%
if (x<9):
    print ("Correct")
else:
    print ("False")
# Out:
# False

# %% [markdown]
# because x = 10 , We writing previously in code

# %% [markdown]
# END
#
# Tommorow :
# - While loop
# - Do While
# - Install Libraries using PyPi
